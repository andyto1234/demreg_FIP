# %%
from mcmc_para import *
import matplotlib.pyplot as plt

# %%
filename = 'SO_EIS_data/eis_20071017_024748.data.h5'

# %%
download_data(filename)
a = ashmcmc(filename)

# Retrieve necessary data from ashmcmc object
Lines, Intensity, Int_error = a.fit_data(plot=False)
ldens = a.read_density()
# Out:
#  + SO_EIS_data/eis_20071017_024748.data.h5 exists, skipping download
#  + SO_EIS_data/eis_20071017_024748.head.h5 exists, skipping download
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found window 0
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_8_185.21
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 185.21 [Angstroms] in window 2
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_8_186.60
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 186.57 [Angstroms] in window 3
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_9_188.50
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Checking fe_9_197.86
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Checking fe_10_184.54
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 184.60 [Angstroms] in window 2
# Error: Wavelength not found! The input data file does not contain a window that observes 188.67499542236328 Angstroms
# Error: Wavelength not found! The input data file does not contain a window that observes 197.81499481201172 Angstroms
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_11_188.22
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 188.20 [Angstroms] in window 4
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_11_188.30
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 188.20 [Angstroms] in window 4
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_12_186.88
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 186.83 [Angstroms] in window 3
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_12_195.12
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 195.11 [Angstroms] in window 6
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_12_192.39
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 192.41 [Angstroms] in window 5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_13_202.04
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 202.07 [Angstroms] in window 9
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_13_203.83
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 203.78 [Angstroms] in window 10
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_14_264.79
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 264.77 [Angstroms] in window 15
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_14_270.52
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 270.48 [Angstroms] in window 16
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_15_284.16
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 284.09 [Angstroms] in window 23
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_16_262.98
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 262.94 [Angstroms] in window 15
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_17_254.87
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Checking fe_22_253.10
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Checking fe_23_263.76
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# Found a wavelength 263.71 [Angstroms] in window 15
# Error: Wavelength not found! The input data file does not contain a window that observes 254.9749984741211 Angstroms
# Error: Wavelength not found! The input data file does not contain a window that observes 253.1699981689453 Angstroms
# Error: Wavelength not found! The input data file does not contain a window that observes 254.9749984741211 Angstroms
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# Checking fe_24_255.10
# Data file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.data.h5
# Header file,
#    /Users/andysh.to/Script/Python_Script/demreg_FIP/SO_EIS_data/eis_20071017_024748.head.h5
# ------------------------------Found 16 usable lines------------------------------
# Found 16 usable lines for DEM
# 2it [00:00, 17.75it/s]
# SO_EIS_data/eis_20071017_024748.fe_08_185_213.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_08_185_213.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.1889797194018927---------------------
# SO_EIS_data/eis_20071017_024748.fe_08_186_601.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_08_186_601.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.270777211497812---------------------
# SO_EIS_data/eis_20071017_024748.fe_10_184_536.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_10_184_536.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.1788894724338683---------------------
# SO_EIS_data/eis_20071017_024748.fe_11_188_216.2c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_11_188_216.2c-0.fit.h5
# 7it [00:00, 19.81it/s]
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.2672862028325702---------------------
# SO_EIS_data/eis_20071017_024748.fe_11_188_299.2c-1.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_11_188_299.2c-1.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.2600786802322776---------------------
# SO_EIS_data/eis_20071017_024748.fe_12_186_880.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_12_186_880.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.2842187619585608---------------------
# SO_EIS_data/eis_20071017_024748.fe_12_195_119.2c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_12_195_119.2c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 0.8655099891949719---------------------
# SO_EIS_data/eis_20071017_024748.fe_12_192_394.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_12_192_394.1c-0.fit.h5
# 11it [00:00, 17.35it/s]
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.0219088569071753---------------------
# SO_EIS_data/eis_20071017_024748.fe_13_202_044.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_13_202_044.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 0.7169691929988862---------------------
# SO_EIS_data/eis_20071017_024748.fe_13_203_830.3c-2.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_13_203_830.3c-2.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 0.8872163635416448---------------------
# SO_EIS_data/eis_20071017_024748.fe_14_264_787.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_14_264_787.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.266244549940878---------------------
# SO_EIS_data/eis_20071017_024748.fe_14_270_519.2c-1.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_14_270_519.2c-1.fit.h5
# 14it [00:00, 17.39it/s]
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.3441789307222092---------------------
# SO_EIS_data/eis_20071017_024748.fe_15_284_160.2c-1.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_15_284_160.2c-1.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.128905623701187---------------------
# SO_EIS_data/eis_20071017_024748.fe_16_262_984.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_16_262_984.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.2645302208651548---------------------
# SO_EIS_data/eis_20071017_024748.fe_23_263_760.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_23_263_760.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 1.262968490856806---------------------
# 15it [00:00, 17.48it/s]
# /Users/andysh.to/Script/Python_Script/demreg_FIP/asheis.py:176: RuntimeWarning: invalid value encountered in divide
#   obs_ratio = m_nom.data / m_denom.data
# SO_EIS_data/eis_20071017_024748.fe_13_203_830.3c-2.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_13_203_830.3c-2.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 0.8872163635416448---------------------
# SO_EIS_data/eis_20071017_024748.fe_13_202_044.1c-0.fit.h5
# Reading fit result from,
#    SO_EIS_data/eis_20071017_024748.fe_13_202_044.1c-0.fit.h5
# INFO: uncertainty should have attribute uncertainty_type. [astropy.nddata.nddata]
# ---------------------Calibrated using Del Zanna et al. 2023; Ratio: 0.7169691929988862---------------------

# %%
xpix = 50
ypix = 240

# %%
plt.figure(figsize=(5,6))
plt.pcolormesh(Intensity[:,:,6])
plt.plot(xpix, ypix, 'rx', markersize=10, markeredgewidth=2)

# %%
from pathlib import Path

output_file = f'{a.outdir}/dem_columns/dem_{xpix}.npz'
# Extract the directory path from the output_file
output_dir = Path(output_file).parent

# Check if the directory exists, and create it if it doesn't
output_dir.mkdir(parents=True, exist_ok=True)

ycoords_out = []
dem_results = []
chi2_results = []
linenames_list = []

logt, emis, linenames = a.read_emissivity(ldens[ypix, xpix])
logt_interp = np.log10(interp_emis_temp(logt.value))
# loc = np.where((np.log10(logt_interp) >= 4) & (np.log10(logt_interp) <= 8))
emis_sorted = a.emis_filter(emis, linenames, Lines)
mcmc_lines = []

mcmc_intensity = []
mcmc_int_error = []
mcmc_emis_sorted = []
dlogt = logt_interp[1]-logt_interp[0]
temps=10**np.arange(np.min(logt_interp),np.max(logt_interp)+dlogt,dlogt)

# %%
for ind, line in enumerate(Lines):
    if (line[:2] == 'fe') and (Intensity[ypix, xpix, ind] > 10):
        mcmc_intensity.append(Intensity[ypix, xpix, ind])
        mcmc_int_error.append(Int_error[ypix, xpix,ind]+Intensity[ypix, xpix,ind]*0.23)
        mcmc_emis_sorted.append(emis_sorted[ind, :])
        mcmc_lines.append(line)

# %%
nt = len(mcmc_emis_sorted[0])
nf = len(mcmc_emis_sorted) 
trmatrix = np.zeros((nt,nf))
for i in range(0,nf):
    trmatrix[:,i] = mcmc_emis_sorted[i]

# %%
import os 
import ChiantiPy.tools.io as chio 

## Get the Chianti DEMs
demDir = os.path.join(os.environ['XUVTOP'], 'dem')
demList = os.listdir(demDir)

# %%
import math

max_iter = 1000
l_emd = False
reg_tweak = 1
rgt_fact = 1.1
dn_in=np.array(mcmc_intensity)
edn_in=np.array(mcmc_int_error)
tresp_logt = logt_interp

# AR
ch_dem_AR = chio.demRead(demList[7])

dem_mod = np.interp(10**tresp_logt,ch_dem_AR['temperature'],ch_dem_AR['dem'])
tresp_dlogt=np.full(nt,0.05)

# %%
# set up our target dem temps
mint=4
maxt=8
# the tresp resolution is 0.05 logt so cant use a resolution finger than that
dlogt=0.05
temps=10**np.arange(mint,maxt+dlogt,dlogt)
mlogt1=([np.mean([(np.log10(temps[i])),np.log10((temps[i+1]))]) \
        for i in np.arange(0,len(temps)-1)])  

demwght0 = 10**np.interp(mlogt1,tresp_logt,np.log10(dem_mod))


mlogt=([np.mean([(np.log10(temps[i])),np.log10((temps[i+1]))]) \
        for i in np.arange(0,len(temps)-1)])
# dem0,edem0,elogt0,chisq0,dn_reg0=dn2dem(dn_in,edn_in,trmatrix,tresp_logt,temps)
# dem0b,edem0b,elogt0b,chisq0b,dn_reg0b=dn2dem(dn_in,edn_in,trmatrix,tresp_logt,temps,l_emd=False)
dem1,edem1,elogt1,chisq1,dn_reg1=dn2dem(dn_in,edn_in,trmatrix,tresp_logt,temps,max_iter=max_iter,emd_int=True,gloci=1,reg_tweak=reg_tweak,rgt_fact=1.3)
# dem1a,edem1a,elogt1a,chisq1a,dn_reg1a=dn2dem(dn_in,edn_in,trmatrix,tresp_logt,
#                                              temps,gloci=1,emd_int=False,
#                                              max_iter=max_iter,l_emd=l_emd,
#                                              reg_tweak=reg_tweak,
#                                              rgt_fact=3)
# dem2a,edem2a,elogt2a,chisq2a,dn_reg2a=dn2dem(dn_in,edn_in,trmatrix,tresp_logt,
#                                              temps,dem_norm0=demwght0/max(demwght0),
#                                              emd_int=True,
#                                              max_iter=max_iter,l_emd=l_emd,
#                                              reg_tweak=reg_tweak,
#                                              rgt_fact=rgt_fact)

# %%
#  Plot it
yr=[2e13,4e30]
xr=[4,8] #np.log10([min(temps),max(temps)])
fig = plt.figure(figsize=(10, 7))
# plt.errorbar(mlogt,dem0,xerr=elogt0,yerr=edem0,fmt='or',\
#              ecolor='lightcoral', elinewidth=3, capsize=0,label='DEM_int, $\chi^2$: {:0.2f}'.format(chisq0))
# plt.errorbar(mlogt,dem0b,xerr=elogt0b,yerr=edem0b,fmt='oy',\
#              ecolor='goldenrod', elinewidth=3, capsize=0,label='DEM_int L_EMD, $\chi^2$: {:0.2f}'.format(chisq0b))
plt.errorbar(mlogt,dem1,xerr=elogt1,yerr=edem1,fmt='xb',\
             ecolor='lightskyblue', elinewidth=3, capsize=0,label='EMD_int, $\chi^2$: {:0.2f}'.format(chisq1))
# plt.errorbar(mlogt,dem1a,xerr=elogt1a,yerr=edem1a,fmt='xb',\
#              ecolor='royalblue', elinewidth=3, capsize=0,label='EMD_int, $\chi^2$: {:0.2f}'.format(chisq1a))
# plt.errorbar(mlogt,dem2a,xerr=elogt2a,yerr=edem2a,fmt='xb',\
#              ecolor='red', elinewidth=3, capsize=0,label='EMD_int, $\chi^2$: {:0.2f}'.format(chisq2a))
plt.plot(tresp_logt,dem_mod,'--',color='grey')
plt.xlabel('$\mathrm{\log_{10}T\;[K]}$')
plt.ylabel('$\mathrm{DEM\;[cm^{-5}\;K^{-1}]}$')
plt.ylim(yr)
plt.xlim(xr)
plt.rcParams.update({'font.size': 16})
plt.yscale('log')
plt.legend()
plt.show()

# print(chisq0,chisq0b,chisq1)
# print(100*dn_reg0/dn_in)
# print(100*dn_reg0b/dn_in)
# print(100*dn_reg1/dn_in)

#  L_EMD not that bad here either.....

# %%
plt.plot(np.log10(temps[0:-1]),dem1)
plt.yscale('log')
chi2 = np.sum(((dn_reg1 - dn_in) / edn_in)**2)
print(f"The sum of chi-square between the two arrays is: {chi2}; No. lines: {len(dn_in)}")
chi2 = np.sum(((dn_reg1 - dn_in) / edn_in)**2)
print(f"The sum of chi-square between the two arrays is: {chi2}; No. lines: {len(dn_in)}")
# Out:
# The sum of chi-square between the two arrays is: 14.928050537541237; No. lines: 14
# The sum of chi-square between the two arrays is: 14.928050537541237; No. lines: 14

# %%
# Calculate chi-square
chi2 = np.sum(((dn_reg1 - dn_in) / edn_in)**2)

print(f"The sum of chi-square between the two arrays is: {chi2}, no. lines: {len(dn_in)}")
# Out:
# The sum of chi-square between the two arrays is: 14.928050537541237, no. lines: 14

# %%
dn_reg1
# Out:
# array([ 78.73822976,  55.34615421, 102.82955563, 286.74569232,
#        175.20117112,  77.78877642, 430.92708414, 137.06028727,
#        313.72675042,  85.21283232,  88.26293008,  56.30304752,
#        469.50811738,  12.72875116])

# %%
dn_in
# Out:
# array([ 76.73460689,  74.22227076, 158.96223783, 384.94418139,
#        251.78457128, 187.18658675, 555.17657717, 199.22996421,
#        430.58156597, 168.05400674, 165.38623461,  91.33730162,
#        570.04095271,  16.73901604])

# %%
edn_in
# Out:
# array([15.13213707, 11.34081591, 35.07784638, 35.66059747, 23.68813429,
#        13.48084419, 23.9767835 ,  9.60031839, 11.75960665])

# %%
chi2 = np.sum(((dn_reg2a - dn_in) / edn_in)**2)
print(f"The sum of chi-square between the two arrays is: {chi2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 chi2 = np.sum(((dn_reg2a - dn_in) / edn_in)**2)
#       2 print(f"The sum of chi-square between the two arrays is: {chi2}")
#
# NameError: name 'dn_reg2a' is not defined

# %%
dn_reg2a
# Out:
# array([121.95360894,  88.1287847 , 206.94883697, 373.95653978,
#        233.13796636, 173.04948026, 475.38550011, 149.84148805,
#        286.92389737, 171.12330792,  85.15394044,  46.88551035,
#        244.02964381])

# %%
dn_reg1a
# Out:
# array([ 87.91262776,  61.26306499,  72.782153  , 192.66476201,
#        117.0819379 ,  61.26420356, 276.09744448,  87.81650804,
#        165.21025809,  70.75306341,  54.23598552,  33.21075483,
#        243.05116286])

# %%
dn_in
# Out:
# array([121.95360791,  88.12878565, 206.94883778, 373.95712795,
#        233.13756467, 173.05197747, 475.38268595, 149.84152602,
#        286.92124528, 171.12677779,  85.15535278,  46.88488274,
#        244.02964439])

# %%
dn_reg0a
# Out:
# array([ 2.67628081,  1.89227304, 11.57428992, 34.81304178, 21.33696421,
#         7.43726515, 48.58435485, 15.44563533, 30.81845605,  6.07536293,
#         5.40551186, 17.96145574])

# %%
import matplotlib.pyplot as plt

# %%
dem0,edem0,elogt0,chisq0,dn_reg0=dn2dem(np.array(mcmc_intensity),np.array(mcmc_int_error),trmatrix,logt_interp,temps)
# Out:
# Warning, positivity loop hit max iterations, so increase max_iter? Or rgt_fact too small?
# /Users/andysh.to/Script/Python_Script/demreg_FIP/demregpy/dn2dem.py:184: RuntimeWarning: divide by zero encountered in log10
#   tr[:, i] = 10**np.interp(logt, tresp_logt, np.log10(truse[:, i]))

# %%
temps
# Out:
# array([1.00000000e+04, 1.09647812e+04, 1.20226428e+04, 1.31825648e+04,
#        1.44543940e+04, 1.58489268e+04, 1.73780015e+04, 1.90545985e+04,
#        2.08929505e+04, 2.29086632e+04, 2.51188480e+04, 2.75422674e+04,
#        3.01994937e+04, 3.31130842e+04, 3.63077725e+04, 3.98106783e+04,
#        4.36515379e+04, 4.78629564e+04, 5.24806847e+04, 5.75439228e+04,
#        6.30956526e+04, 6.91830028e+04, 7.58576492e+04, 8.31762530e+04,
#        9.12009419e+04, 9.99998378e+04, 1.09647635e+05, 1.20226233e+05,
#        1.31825434e+05, 1.44543705e+05, 1.58489011e+05, 1.73779733e+05,
#        1.90545676e+05, 2.08929166e+05, 2.29086260e+05, 2.51188073e+05,
#        2.75422227e+05, 3.01994447e+05, 3.31130305e+05, 3.63077136e+05,
#        3.98106137e+05, 4.36514671e+05, 4.78628788e+05, 5.24805996e+05,
#        5.75438295e+05, 6.30955502e+05, 6.91828906e+05, 7.58575262e+05,
#        8.31761181e+05, 9.12007940e+05, 9.99996756e+05, 1.09647457e+06,
#        1.20226038e+06, 1.31825221e+06, 1.44543471e+06, 1.58488754e+06,
#        1.73779451e+06, 1.90545367e+06, 2.08928827e+06, 2.29085888e+06,
#        2.51187665e+06, 2.75421780e+06, 3.01993957e+06, 3.31129768e+06,
#        3.63076547e+06, 3.98105492e+06, 4.36513963e+06, 4.78628012e+06,
#        5.24805145e+06, 5.75437361e+06, 6.30954479e+06, 6.91827784e+06,
#        7.58574031e+06, 8.31759831e+06, 9.12006460e+06, 9.99995134e+06,
#        1.09647279e+07, 1.20225843e+07, 1.31825007e+07, 1.44543236e+07,
#        1.58488497e+07, 1.73779170e+07, 1.90545058e+07, 2.08928488e+07,
#        2.29085517e+07, 2.51187258e+07, 2.75421333e+07, 3.01993467e+07,
#        3.31129231e+07, 3.63075958e+07, 3.98104846e+07, 4.36513255e+07,
#        4.78627235e+07, 5.24804293e+07, 5.75436428e+07, 6.30953455e+07,
#        6.91826662e+07, 7.58572801e+07, 8.31758482e+07, 9.12004981e+07,
#        9.99993512e+07, 1.09647101e+08])

# %%
logt_interp
# Out:
# array([1.00000000e+04, 1.09647812e+04, 1.20226426e+04, 1.31825635e+04,
#        1.44543926e+04, 1.58489248e+04, 1.73780000e+04, 1.90546172e+04,
#        2.08929688e+04, 2.29086836e+04, 2.51188691e+04, 2.75422910e+04,
#        3.01995176e+04, 3.31131094e+04, 3.63078008e+04, 3.98107070e+04,
#        4.36515703e+04, 4.78629922e+04, 5.24807188e+04, 5.75440234e+04,
#        6.30957617e+04, 6.91831250e+04, 7.58577812e+04, 8.31763906e+04,
#        9.12010938e+04, 1.00000000e+05, 1.09647812e+05, 1.20226422e+05,
#        1.31825641e+05, 1.44543922e+05, 1.58489250e+05, 1.73779984e+05,
#        1.90545953e+05, 2.08929469e+05, 2.29086828e+05, 2.51188703e+05,
#        2.75422906e+05, 3.01995188e+05, 3.31131094e+05, 3.63078000e+05,
#        3.98107094e+05, 4.36515688e+05, 4.78629906e+05, 5.24807188e+05,
#        5.75440250e+05, 6.30957625e+05, 6.91831188e+05, 7.58577750e+05,
#        8.31763938e+05, 9.12010938e+05, 1.00000000e+06, 1.09647812e+06,
#        1.20226425e+06, 1.31825638e+06, 1.44543925e+06, 1.58489250e+06,
#        1.73779988e+06, 1.90545950e+06, 2.08929462e+06, 2.29086575e+06,
#        2.51188425e+06, 2.75422900e+06, 3.01995175e+06, 3.31131100e+06,
#        3.63078000e+06, 3.98107075e+06, 4.36515700e+06, 4.78629900e+06,
#        5.24807800e+06, 5.75440250e+06, 6.30957600e+06, 6.91831200e+06,
#        7.58577750e+06, 8.31763900e+06, 9.12010900e+06, 1.00000000e+07,
#        1.09647810e+07, 1.20226420e+07, 1.31825640e+07, 1.44543930e+07,
#        1.58489250e+07, 1.73780000e+07, 1.90545960e+07, 2.08929460e+07,
#        2.29086580e+07, 2.51188420e+07, 2.75422600e+07, 3.01995180e+07,
#        3.31131100e+07, 3.63078000e+07, 3.98107080e+07, 4.36515680e+07,
#        4.78629920e+07, 5.24807800e+07, 5.75440240e+07, 6.30957640e+07,
#        6.91831200e+07, 7.58577760e+07, 8.31763920e+07, 9.12010880e+07,
#        1.00000000e+08])

# %%
temps
# Out:
# array([inf, inf, inf, ..., inf, inf, inf])

# %%
calc_composition(filename, np_file, line_databases, args.cores)

# Change "[processing]" to "[processed]" in filenames.txt after processing is finished
processed_filename = filename + " [processed]"
update_filenames_txt(processing_filename, processed_filename)
